# %%
import pandas as pd
import numpy as np
import datetime

# %%
train_data = pd.read_csv('AI Fluency - Training Data.csv')
test_data = pd.read_csv('AI Fluency - Testing Data.csv')

# %%
train_data.head()
# Out:
#     timestamp  Asset_ID  Count        Open      High       Low         Close  \
# 0  1514764860         1  229.0  13835.1940  14013.80  13666.11  13850.176000
# 1  1514764860         6  173.0    738.3025    746.00    732.51    738.507500
# 2  1514764860         9  167.0    225.3300    227.78    222.98    225.206667
# 3  1514764920         1  235.0  13835.0360  14052.30  13680.00  13828.102000
# 4  1514764920         6  192.0    738.5075    745.14    732.49    738.260000
#
#        Volume          VWAP    Target  Index
# 0   31.550062  13827.062093 -0.014643      0
# 1  335.987856    738.839291 -0.004809      1
# 2  411.896642    225.197944 -0.009791      2
# 3   31.046432  13840.362591 -0.015037      3
# 4  232.793141    738.268967 -0.004441      4

# %%
test_data.head()
# Out:
#     timestamp  Asset_ID   Count          Open      High       Low  \
# 0  1608709020         1  1344.0  23551.750000  23575.68  23536.89
# 1  1608709080         1  2305.0  23547.891429  23601.19  23531.17
# 2  1608709140         1  1967.0  23573.493474  23590.52  23554.99
# 3  1608709200         1  2056.0  23564.556250  23583.01  23520.91
# 4  1608709260         1  2415.0  23548.942857  23559.03  23516.50
#
#           Close      Volume          VWAP  Target  Index
# 0  23550.561429   73.343676  23554.052255     NaN      0
# 1  23575.522857  116.255885  23566.178908     NaN      1
# 2  23572.870150   75.640431  23571.855833     NaN      2
# 3  23549.337500   83.606277  23555.485659     NaN      3
# 4  23538.265714  101.517017  23533.428771     NaN      4

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5503390 entries, 0 to 5503389
# Data columns (total 11 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  int64
#  1   Asset_ID   int64
#  2   Count      float64
#  3   Open       float64
#  4   High       float64
#  5   Low        float64
#  6   Close      float64
#  7   Volume     float64
#  8   VWAP       float64
#  9   Target     float64
#  10  Index      int64
# dtypes: float64(8), int64(3)
# memory usage: 461.9 MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375849 entries, 0 to 1375848
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   timestamp  1375849 non-null  int64
#  1   Asset_ID   1375849 non-null  int64
#  2   Count      1375849 non-null  float64
#  3   Open       1375849 non-null  float64
#  4   High       1375849 non-null  float64
#  5   Low        1375849 non-null  float64
#  6   Close      1375849 non-null  float64
#  7   Volume     1375849 non-null  float64
#  8   VWAP       1375849 non-null  float64
#  9   Target     0 non-null        float64
#  10  Index      1375849 non-null  int64
# dtypes: float64(8), int64(3)
# memory usage: 115.5 MB

# %%
train_data['timestamp']=[datetime.datetime.fromtimestamp(each) for each in train_data['timestamp']]
test_data['timestamp']=[datetime.datetime.fromtimestamp(each) for each in test_data['timestamp']]

# %%
train_data.head(500)
# Out:
#               timestamp  Asset_ID  Count          Open      High       Low  \
# 0   2018-01-01 05:31:00         1  229.0  13835.194000  14013.80  13666.11
# 1   2018-01-01 05:31:00         6  173.0    738.302500    746.00    732.51
# 2   2018-01-01 05:31:00         9  167.0    225.330000    227.78    222.98
# 3   2018-01-01 05:32:00         1  235.0  13835.036000  14052.30  13680.00
# 4   2018-01-01 05:32:00         6  192.0    738.507500    745.14    732.49
# ..                  ...       ...    ...           ...       ...       ...
# 495 2018-01-01 08:16:00         1  393.0  13389.284000  13480.00  13338.97
# 496 2018-01-01 08:16:00         6   90.0    724.757500    727.61    722.08
# 497 2018-01-01 08:16:00         9  273.0    217.185000    220.83    213.65
# 498 2018-01-01 08:17:00         1  324.0  13408.258000  13480.00  13334.89
# 499 2018-01-01 08:17:00         6   38.0    724.296667    727.62    722.30
#
#             Close       Volume          VWAP    Target  Index
# ...

# %%
train_data['Dates'] = pd.to_datetime(train_data['timestamp']).dt.date
train_data['Time'] = pd.to_datetime(train_data['timestamp']).dt.time
test_data['Dates'] = pd.to_datetime(test_data['timestamp']).dt.date
test_data['Time'] = pd.to_datetime(test_data['timestamp']).dt.time

# %%
train_data.head()
# Out:
#             timestamp  Asset_ID  Count        Open      High       Low  \
# 0 2018-01-01 05:31:00         1  229.0  13835.1940  14013.80  13666.11
# 1 2018-01-01 05:31:00         6  173.0    738.3025    746.00    732.51
# 2 2018-01-01 05:31:00         9  167.0    225.3300    227.78    222.98
# 3 2018-01-01 05:32:00         1  235.0  13835.0360  14052.30  13680.00
# 4 2018-01-01 05:32:00         6  192.0    738.5075    745.14    732.49
#
#           Close      Volume          VWAP    Target  Index       Dates  \
# 0  13850.176000   31.550062  13827.062093 -0.014643      0  2018-01-01
# 1    738.507500  335.987856    738.839291 -0.004809      1  2018-01-01
# 2    225.206667  411.896642    225.197944 -0.009791      2  2018-01-01
# 3  13828.102000   31.046432  13840.362591 -0.015037      3  2018-01-01
# 4    738.260000  232.793141    738.268967 -0.004441      4  2018-01-01
#
#        Time
# 0  05:31:00
# 1  05:31:00
# 2  05:31:00
# 3  05:32:00
# 4  05:32:00

# %%
def day_date(dates):
    date = str(dates)
    year, month, day  = date.split('-')
    day_name = datetime.date(int(year), int(month), int(day)) 
    return day_name.strftime("%A")

# %%
train_data['day']=[day_date(each) for each in train_data['Dates']]
test_data['day']=[day_date(each) for each in test_data['Dates']]

# %%
train_data.head()
# Out:
#             timestamp  Asset_ID  Count        Open      High       Low  \
# 0 2018-01-01 05:31:00         1  229.0  13835.1940  14013.80  13666.11
# 1 2018-01-01 05:31:00         6  173.0    738.3025    746.00    732.51
# 2 2018-01-01 05:31:00         9  167.0    225.3300    227.78    222.98
# 3 2018-01-01 05:32:00         1  235.0  13835.0360  14052.30  13680.00
# 4 2018-01-01 05:32:00         6  192.0    738.5075    745.14    732.49
#
#           Close      Volume          VWAP    Target  Index       Dates  \
# 0  13850.176000   31.550062  13827.062093 -0.014643      0  2018-01-01
# 1    738.507500  335.987856    738.839291 -0.004809      1  2018-01-01
# 2    225.206667  411.896642    225.197944 -0.009791      2  2018-01-01
# 3  13828.102000   31.046432  13840.362591 -0.015037      3  2018-01-01
# 4    738.260000  232.793141    738.268967 -0.004441      4  2018-01-01
#
#        Time     day
# 0  05:31:00  Monday
# 1  05:31:00  Monday
# 2  05:31:00  Monday
# 3  05:32:00  Monday
# ...

# %%
grouped = train_data.groupby("day")
monday= grouped.get_group('Monday')

# %%
monday
# Out:
#                   timestamp  Asset_ID   Count          Open          High  \
# 0       2018-01-01 05:31:00         1   229.0  13835.194000  14013.800000
# 1       2018-01-01 05:31:00         6   173.0    738.302500    746.000000
# 2       2018-01-01 05:31:00         9   167.0    225.330000    227.780000
# 3       2018-01-01 05:32:00         1   235.0  13835.036000  14052.300000
# 4       2018-01-01 05:32:00         6   192.0    738.507500    745.140000
# ...                     ...       ...     ...           ...           ...
# 5503385 2021-05-03 16:07:00         4   811.0      0.386032      0.386550
# 5503386 2021-05-03 16:08:00         4   630.0      0.385957      0.386280
# 5503387 2021-05-03 16:09:00         4  1346.0      0.385808      0.386093
# 5503388 2021-05-03 16:10:00         4  1600.0      0.385059      0.385680
# 5503389 2021-05-03 16:11:00         4  1007.0      0.384418      0.385000
#
#                  Low         Close        Volume          VWAP    Target  \
# ...

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
X=input_data["Comments_Summary_Description"]
Y=input_data['Type_Mapping']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
